# %%
# What are 10 (or more) questions that you hope to answer through your data analysis?

No. | Question
:-:|:-
1. | What is the engineering median pay for recent college graduates?
2. | How does the engineering median pay compare to the business median pay?
3. | Which engineering major has the highest pay?
4. | How does industrial engineering’s pay compare to the highest engineering pay?
5. | Out of all the majors, which major has the potential to make the most money?
6. | Is it more likely to find a job as an aerospace engineering major or industrial engineering major?
7. | How likely is it to come out of college with a full time job as an industrial engineering major?
8. | Which non-engineering majors has the potential of making the most?
9. | How does engineering pay compare to computer and mathematics pay?
10. | Which major has the highest pay and is most likely to find a job out of college?
# Out:
#   Input In [4]
#     No. | Question
#         ^
# SyntaxError: invalid syntax

# %%
import pandas
import seaborn as sns
import matplotlib.pyplot as plt

pandas.options.display.max_columns = None
pandas.options.display.max_rows = None

college_salaries = pandas.read_csv("recent-grads.csv")

college_salaries
# Out:
#      Rank  Major_code                                              Major  \
# 0       1        2419                              PETROLEUM ENGINEERING
# 1       2        2416                     MINING AND MINERAL ENGINEERING
# 2       3        2415                          METALLURGICAL ENGINEERING
# 3       4        2417          NAVAL ARCHITECTURE AND MARINE ENGINEERING
# 4       5        2405                               CHEMICAL ENGINEERING
# 5       6        2418                                NUCLEAR ENGINEERING
# 6       7        6202                                  ACTUARIAL SCIENCE
# 7       8        5001                         ASTRONOMY AND ASTROPHYSICS
# 8       9        2414                             MECHANICAL ENGINEERING
# 9      10        2408                             ELECTRICAL ENGINEERING
# 10     11        2407                               COMPUTER ENGINEERING
# 11     12        2401                              AEROSPACE ENGINEERING
# ...

# %%
''' Ansering question 1: What is the engineering median pay for recent college graduates?'''

avg_eng_sal = college_salaries[ college_salaries['Major_category'] == 'Engineering']['Median']

avg_eng_sal.mean()
# Out:
# 57382.75862068965

# %%
import seaborn as sns
# sns.barplot(x = college_salaries[college_salaries['Major_category'] == 'Engineering'], y = college_salaries['Median'])

sns.barplot(x = college_salaries['Major_category'], y = college_salaries['Median'])
# Out:
# <AxesSubplot:xlabel='Major_category', ylabel='Median'>

# %%
''' Answering question 2: How does the engineering median pay compare to the business median pay?'''

avg_eng_sal = college_salaries[ college_salaries['Major_category'] == 'Engineering']['Median']

avg_bus_sal = college_salaries[ college_salaries['Major_category'] == 'Business']['Median']

avg_eng_sal.mean()
avg_bus_sal.mean()
# Out:
# 43538.46153846154

# %%
import seaborn as sns

sns.barplot(x = avg_eng_sal.mean(), y = avg_bus_sal.mean())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [14], in <cell line: 3>()
#       1 import seaborn as sns
# ----> 3 sns.barplot(x = avg_eng_sal.mean(), y = avg_bus_sal.mean())
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_decorators.py:46, in _deprecate_positional_args.<locals>.inner_f(*args, **kwargs)
#      36     warnings.warn(
#      37         "Pass the following variable{} as {}keyword arg{}: {}. "
#      38         "From version 0.12, the only valid positional argument "
#    (...)
#      43         FutureWarning
#      44     )
#      45 kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46 return f(**kwargs)
#
# ...

# %%
''' Answering question 3: Which engineering major has the highest pay?'''

engineering_majors = college_salaries[ college_salaries['Major_category'] == 'Engineering']['P75th']

engineering_majors.max()
# Out:
# 125000

# %%
''' Answering question 4: How does industrial engineering’s pay compare to the highest engineering pay?'''

industrial_salary = college_salaries[ college_salaries['Major'] == 'INDUSTRIAL AND MANUFACTURING ENGINEERING']['P75th']

industrial_salary

engineering_majors = college_salaries[ college_salaries['Major_category'] == 'Engineering']['P75th']

engineering_majors.max()
# Out:
# 16    67000
# Name: P75th, dtype: int64

# %%
import seaborn as sns

ind_vs_highest = college_salaries[college_salaries['Major'] == 'INDUSTRIAL AND MANUFACTURING ENGINEERING', college_salaries['Major'] == 'PETROLEUM ENGINEERING']

sns.barplot(x = df['ind_vs_highest'], y = df['P75th'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\indexes\base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\_libs\index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\_libs\index.pyx:142, in pandas._libs.index.IndexEngine.get_loc()
#
# TypeError: '(0      False
# 1      False
# 2      False
# 3      False
# 4      False
# 5      False
# 6      False
# 7      False
# 8      False
# 9      False
# 10     False
# 11     False
# 12     False
# 13     False
# 14     False
# 15     False
# 16      True
# 17     False
# 18     False
# ...

# %%
''' Answering question 5: Out of all the majors, which major has the potential to make the most money?'''

highest_pay = college_salaries['P75th']

highest_pay.max()
# Out:
# 125000

# %%
''' Answering question 6: Is it more likely to find a job as an aerospace engineering major or industrial engineering major?'''

# %%
''' Answering question 7: How likely is it to come out of college with a full time job as an industrial engineering major?'''

# %%
''' Answering question 8: Which non-engineering majors has the potential of making the most?'''

avg_non_eng_sal = college_salaries[ college_salaries['Major_category'] == 'Physical Sciences, Business, Law & Public Policy, Computers & Mathematics, Agriculture & Natural Resources, Industrial Arts & Consumer Services, Arts, Health, Social Science, Biology & Life Science, Physical Sciences, Education']['Median']

avg_non_eng_sal.mean()
# Out:
# nan

# %%
''' Answering question 9: How does engineering pay compare to computer and mathematics pay?'''

avg_eng_sal = college_salaries[ college_salaries['Major_category'] == 'Engineering']['Median']

avg_math_sal = college_salaries[ college_salaries['Major_category'] == 'Computers & Mathematics']['Median']

avg_eng_sal.mean()
avg_math_sal.mean()
# Out:
# 57382.75862068965

# %%
''' Answering question 10: Which major has the highest pay and is most likely to find a job out of college?'''
